# %% [markdown]
# # Звіт до роботи

# %% [markdown]
# ## Тема:Основи програмування на Python

# %% [markdown]
# Мета роботи:Навчитись застосовувати основні конструкції Python, виконати приклади коду та створити власні приклади.

# %% [markdown]
# Виконання роботи:
# Завдання 1 (Крок 2: Основні типи даних)
# Розробили / Створили: змінні різних типів (str, int, float, list, dict, tuple, set).
# Програма вивела значення: типи змінних або їхній вміст.
# Отримано наступні результати: Типи змінних: <class 'str'> <class 'int'> <class 'float'> <class 'list'> <class 'dict'> <class 'tuple'> <class 'set'>
# Навчились: створювати змінні різних типів та працювати з ними.
#
# ![Опис зображення](pictures/img1.png)
# ![Опис зображення](pictures/img2.png)

# %% [markdown]
# Завдання 2 (Крок 3: Константи та зарезервовані слова)
# Розробили / Створили: приклади вбудованих констант (True, None) та перегляд зарезервованих слів Python.
# Програма вивела значення: текст з константами та списком ключових слів.
# Отримано наступні результати: Перша константа: True Друга константа (приклад форматування): None
# Here is a list of the Python keywords. Enter any keyword to get more help.
# False class from or None continue global pass True def if raise and del import return as elif in try assert else is while async except lambda with await finally nonlocal yield break for not
# Навчились: виводити константи, використовувати форматування рядків і переглядати keywords.
# ![Опис картинки](pictures/img3.png)

# %% [markdown]
# Завдання 3 (Крок 4: Вбудовані функції)
# Розробили / Створили: приклади роботи вбудованих функцій (abs(), len(), sum()).
# Програма вивела значення: обчислення абсолютного значення, довжини списку, суми елементів.
# Отримано наступні результати: Модуль числа -12.5 дорівнює: 12.5 Максимальне з чисел 3, 7, 5: 7 Довжина списку c: 5
# Навчились: використовувати базові вбудовані функції Python.
# ![Опис картинки](pictures/img4.png)

# %% [markdown]
# Завдання 4 (Крок 5: Цикли)
# Розробили / Створили: приклади циклів for і while.
# Програма вивела значення: ітерації елементів списку, лічильник циклу.
# Отримано наступні результати: На позиції 0 знаходиться літера a На позиції 1 знаходиться літера b На позиції 2 знаходиться літера c Цикл for завершено. Поточне значення n: 0 Поточне значення n: 1 Поточне значення n: 2 Цикл while завершено.
# Навчились: писати цикли та використовувати range().
# ![Опис картинки](pictures/img5.png)
# ![Опис картинки](pictures/img6.png)

# %% [markdown]
# Завдання 5 (Крок 6: Розгалуження)
# Розробили / Створили: приклади if-else та умовний вираз.
# Програма вивела значення: випадкове значення змінної та результат перевірки.
# Отримано наступні результати: Число 1 менше за 5
# Навчились: застосовувати умовні оператори.
# ![Опис картинки](pictures/img7.png)

# %% [markdown]
# Завдання 6 (Крок 7: try-except-finally)
# Розробили / Створили: код для обробки помилок (ZeroDivisionError).
# Програма вивела значення: повідомлення про помилку та виконання блоку finally.
# Отримано наступні результати: Виникла помилка: division by zero Блок finally виконується завжди.
# Навчились: обробляти виключення у Python.
# ![Опис картинки](pictures/img8.png)

# %% [markdown]
# Завдання 7 (Крок 8: Контекст-менеджер with)
# Розробили / Створили: приклад роботи з файлом через with.
# Програма вивела значення: рядки файлу (перші 5–10 рядків).
# Отримано наступні результати: 1) Це приклад контекст-менеджера з Python.
# Навчились: працювати з контекст-менеджерами.
# ![Опис картинки](pictures/img9.png)

# %% [markdown]
# Завдання 8 (Крок 9: Lambda)
# Розробили / Створили: приклад лямбда-функції і класичної функції для порівняння.
# Програма вивела значення: текстові результати виклику функцій.
# Навчились: створювати та викликати lambda-функції
# ![Опис картинки](pictures/img10.png)

# %% [markdown]
# Завдання 9 (Крок 10: AI-приклади)
# Розробили / Створили: приклади коду, згенеровані AI (ChatGPT), та їх виконання.
# Програма вивела значення: обчислені результати списків або інші приклади.
# Навчились: застосовувати AI для генерації прикладів Python.
# ![Опис картинки](pictures/img11.png)
# ![Опис картинки](pictures/img12.png)
# ![Опис картинки](pictures/img13.png)

# %% [markdown]
# Висновок
#  • Що зроблено в роботі:
# Вивчено основні конструкції Python, виконано практичні приклади у Jupyter Notebook.
#  • Чи досягнуто мети роботи:
# Так, мету досягнуто: навчилися працювати з типами даних, циклами, розгалуженнями, try-except, контекст-менеджерами та лямбда-функціями.
#  • Які нові знання отримано:
# Основи синтаксису Python, робота з Jupyter Notebook, використання вбудованих функцій, обробка помилок, робота з файлами.
#  • Чи вдалось відповісти на всі питання задані в ході роботи:
# Так, усі запитання опрацьовані і продемонстровані прикладами.
#  • Чи вдалося виконати всі завдання:
# Так, всі завдання виконані.
#  • Чи виникли складності у виконанні завдання:
# Невеликі труднощі були при синтаксисі тернарного if-else та суміщенні f-рядків з .format(), але вони усунуті.
#  • Чи подобається такий формат здачі роботи (Feedback):
# Так, формат зручний, особливо використання Jupyter Notebook і вставка скріншотів.
#  • Побажання для покращення (Suggestions):
# Можна додати більше інтерактивних прикладів та завдань на комбінування конструкцій Python у одному прикладі.
